# %%
'''Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.'''
'''
>sns.relplot it plots that graph presenting relationship between the two values
>sns.catplot it plots the categorical graph
Categorical scatterplots (kind="strip")
Categorical swarmplots (kind="swarm")
Categorical boxplots (kind="box")
Categorical violinplots (kind="violin")
Categorical bar plots (kind="bar")
Categorical count plots (kind="count")
>sns.jointplot used to create joint plots
Scatter plots (kind="scatter")
Hexbin plots (kind="hex")
Kernel density estimate plots (kind="kde")
Regression plots (kind="reg")
>sns.displot is used to create histograms and density plots
Histograms (kind="hist")
Density plots (kind="kde")
Rug plots (kind="rug")
Histograms with density estimates (kind="hist" and kde=True)
>sns.pairplot  is used to create a pairwise plot. '''
# Out:
# 'sb.relplot '

# %%
###practicing
import seaborn as sns
ir=sns.load_dataset("iris")
#sns.catplot(ir,kind="violin")
#sns.violinplot(ir)
#sns.displot(ir)
sns.jointplot(ir)
#sns.pairplot(ir)

# %%
'''Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
"timepoint" and y = "signal" for different events and regions.'''
fmri=sns.load_dataset("fmri")
print(fmri.head())
sns.lineplot(x=fmri.timepoint,y=fmri.signal,hue="event",style="region",data=fmri)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
'''Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
'pclass', y = 'age' and y = 'fare'.'''
titanic=sns.load_dataset("titanic")
sns.boxplot(x=titanic.pclass,y=titanic.fare)
sns.boxplot(x=titanic.pclass,y=titanic.age)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
'''Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
parameter for the 'cut' column of the diamonds dataset.'''
di=sns.load_dataset("diamonds")
sns.histplot(x="price",hue="cut",data=di)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
'''Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
of the iris dataset.'''
ir=sns.load_dataset("iris")
sns.pairplot(ir,hue="species")

# %%
sns.load_dataset("flights").head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
'''Que 6: Use the "flights" dataset from seaborn to plot a heatmap.'''
fl=sns.load_dataset("flights")
#converting into row column and values using pivot function
pivo=fl.pivot(index="year",columns="month",values="passengers")
sns.heatmap(pivo)
# Out:
# <Axes: xlabel='month', ylabel='year'>
