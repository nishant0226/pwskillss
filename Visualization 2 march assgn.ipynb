# %%
'''Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.'''
#Matplotlib is used for visualisation and analysis of data
#other platforms are Line plot,scatter,bar,barh,histograms,pie chart
# Out:
# 'Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of\nMatplotlib.'

# %%
'''Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
Note: Also add title, xlabel, and ylabel to the plot.'''
#scatter plot shows the points on the graph where coordinates do not connect each other  
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y,c="g",marker="o")
plt.xlabel("this is x axis")
plt.ylabel("this is y axis")
plt.title("solution for Q2")
# Out:
# Text(0.5, 1.0, 'solution for Q2')

# %%
'''Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])'''

x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
x2=  np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])
f,a=plt.subplots(nrows=2,ncols=2,figsize=(6,8))
a[0,0].plot(x1,y1)
a[0,1].plot(x2,y2)
a[1,0].plot(x3,y3)
a[1,1].plot(x4,y4)

# %%
'''Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
'''
'''A bar plot is a type of chart that displays categorical data with rectangular bars. 
The length of each bar is proportional to the value it represents. 
Bar plots can be used to show comparisons between different categories or to display the distribution of a single categorical variable.'''
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
'''Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
'''
'''A box plot is a type of chart that shows the distribution of a set of data values. 
It displays the range, median, and quartiles of the data in a compact and easy-to-understand format.
The box plot consists of a box, which represents the middle 50% of the data, and whiskers, which extend from the box to show the range of the data. 
The line inside the box represents the median of the data. Outliers are plotted as individual points outside the whiskers.
Box plots are used to visualize the spread and skewness of a set of data values, and to compare the distributions of different data sets. 
They are particularly useful for identifying outliers and extreme values in a dataset'''
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]
plt.boxplot(data)
plt.show()
